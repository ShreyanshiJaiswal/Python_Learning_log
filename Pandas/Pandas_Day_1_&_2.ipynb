# %% [markdown]
# <a href="https://colab.research.google.com/github/ShreyanshiJaiswal/Python_Learning_log/blob/main/Pandas/Pandas_Day_1_%26_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# Here we are importing the pandas as pd but we can also write anything else it will work the same, but pd is suggested mostly as it's common.

# %% [markdown]
# Google Colab already has Pandas pre-installed, so you don’t need to run pip install pandas there. Just import and start using it.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-328da757-3419-4bb8-8d00-5508e72e8331" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-328da757-3419-4bb8-8d00-5508e72e8331">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# You can upload your CSV file directly in Colab using this code snippet: Here we have uploaded the orders.csv file

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ea9cb5ef-e574-41df-9c3a-bb7039c5bb5e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ea9cb5ef-e574-41df-9c3a-bb7039c5bb5e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Re running the same code to upload another file that is returns.csv this time

# %%
data ={
      "Name":['Ankit','Ashu','Ashwani'],
      "Age":[25,45,68],
      "Salary":[25000,49000,56000]}
df =pd.DataFrame(data)
df
# Out:
#       Name  Age  Salary
# 0    Ankit   25   25000
# 1     Ashu   45   49000
# 2  Ashwani   68   56000

# %% [markdown]
# Here above we have written df which means data frame, like in python we have write print to print something but in case of pandas we can simply write df to print it.

# %%
df =pd.read_csv('orders.csv')
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %% [markdown]
# Above we have read the file order.csv. Also this file is small as it has less data but generally files are not this small so we can write df.head(), which is shown below

# %%
df = pd.read_csv('orders.csv')
df.head()
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0
# 4  OFF-ST-10000760  Office Supplies   22.4         2     2.5

# %% [markdown]
# The above query will give only top 5 cells of the table.

# %%
df.head(10)
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 5  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
# 6  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
# 7  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
# 8  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
# 9  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# ...

# %% [markdown]
# if we pass the parameter in the head then we can get desired number of top records from the table. In above case we are getting top 10 from above.

# %%
df.tail(10)
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 40  CA-2019-117415  27-12-2019  31-12-2019  Standard Class    SN-20710
# 41  CA-2021-120999  10-09-2021  15-09-2021  Standard Class    LC-16930
# 42  CA-2020-101343  17-07-2020  22-07-2020  Standard Class    RA-19885
# 43  CA-2021-139619  19-09-2021  23-09-2021  Standard Class    ES-14080
# 44  CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 45  CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 46  CA-2018-146703  20-10-2018  25-10-2018    Second Class    PO-18865
# 47  CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900
# 48  CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900
# 49  CA-2019-115742  18-04-2019  22-04-2019  Standard Class    DP-13000
#
#      region       product_id         category  sales  quantity  profit
# 40  Central  TEC-PH-10000486       Technology  371.2         4    41.8
# ...

# %% [markdown]
# This will give us last 10 records from the table.

# %%
df.dtypes
# Out:
# order_id        object
# order_date      object
# ship_date       object
# ship_mode       object
# customer_id     object
# region          object
# product_id      object
# category        object
# sales          float64
# quantity         int64
# profit         float64
# dtype: object

# %% [markdown]
# The above code tells us the data types of the columns we have in our table. Also it can be seen here that for text data it's generally called string and also for dates it's called date time but here in pandas it by default takes it as object. It is nothing but the type of data we have in pandas. Also later we will understand how we can convert this.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   order_id     50 non-null     object
#  1   order_date   50 non-null     object
#  2   ship_date    50 non-null     object
#  3   ship_mode    50 non-null     object
#  4   customer_id  50 non-null     object
#  5   region       50 non-null     object
#  6   product_id   50 non-null     object
#  7   category     50 non-null     object
#  8   sales        50 non-null     float64
#  9   quantity     50 non-null     int64
#  10  profit       50 non-null     float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 4.4+ KB

# %% [markdown]
# It is telling more info about our data

# %%
df.describe()
# Out:
#              sales   quantity       profit
# count    50.000000  50.000000    50.000000
# mean    300.792000   3.920000   -20.550000
# std     547.564035   1.977836   251.767027
# min       2.500000   2.000000 -1665.100000
# 25%      20.075000   2.000000     2.500000
# 50%      74.650000   3.000000     8.350000
# 75%     249.875000   5.000000    17.650000
# max    3083.400000   9.000000   240.300000

# %% [markdown]
# It is telling some statistics about the columns we have in our dataset, also it can only be done on numerical columns that's why not every column is included here. As it makes sense here that we can perform the statistics only on the numerical value columns.

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_id',
#        'region', 'product_id', 'category', 'sales', 'quantity', 'profit'],
#       dtype='object')

# %% [markdown]
# The above will show us the names of columns we have in our table

# %%
df.columns=['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_id',
       'region', 'product_id', 'category', 'sales', 'quantity', 'profit']
df.head(5)
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0
# 4  OFF-ST-10000760  Office Supplies   22.4         2     2.5

# %% [markdown]
# This will give us the column names whereas if we change the names and the order in the dataset we will get the same data but the column name only that will be change. Understanding this with an example.

# %%
df.columns=['order_date','order_id', 'ship_date', 'ship_mode', 'customer_id',
       'region', 'product_id', 'category', 'sales', 'quantity', 'profit']
df.head(5)
# Out:
#        order_date    order_id   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0
# 4  OFF-ST-10000760  Office Supplies   22.4         2     2.5

# %% [markdown]
# Here I have changed the column names, I have printed order_date first then its id, but as it can be seen that there is no exchange in the actual data in our dataset.

# %%
df.columns=['order_date','order_id', 'ship_date', 'ship_mode', 'customer_key',
       'region', 'product_id', 'category', 'sales', 'quantity', 'profit']
df.head(5)
# Out:
#        order_date    order_id   ship_date       ship_mode customer_key region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class     CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class     CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class     DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class     SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class     SO-20335  South
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0
# 4  OFF-ST-10000760  Office Supplies   22.4         2     2.5

# %% [markdown]
# Here we have renamed the customer_id as customer_key. we can also use the rename function but it's easy too.

# %% [markdown]
# DAY **2**

# %% [markdown]
# So, generally we have a header in our csv file and it's the first line but it can also be possible that we don't have it and from the first row we have the data.

# %%
import pandas as pd
df = pd.read_csv('orders.csv', header = None)
df
# Out:
#                 0           1           2               3            4   \
# 0         order_id  order_date   ship_date       ship_mode  customer_id
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class     CG-12520
# 2   CA-2020-152156  08-11-2020  11-11-2020    Second Class     CG-12520
# 3   CA-2020-138688  12-06-2020  16-06-2020    Second Class     DV-13045
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class     SO-20335
# 5   US-2019-108966  11-10-2019  18-10-2019  Standard Class     SO-20335
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class     BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class     BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class     BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class     BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class     BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class     BH-11710
# ...

# %% [markdown]
# Here pandas is assuming 1st row as a part of the data since we have writte we have no header in our csv file. But since we have the header in our csv file so we will write it ok. The code is given below

# %%
df =pd.read_csv('orders.csv')
df.head(5)
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0
# 4  OFF-ST-10000760  Office Supplies   22.4         2     2.5

# %%
col =['order_id','order_date','ship_date']
df[col]
#df[['order_id','order_date','ship_date']]
# Out:
#           order_id  order_date   ship_date
# 0   CA-2020-152156  08-11-2020  11-11-2020
# 1   CA-2020-152156  08-11-2020  11-11-2020
# 2   CA-2020-138688  12-06-2020  16-06-2020
# 3   US-2019-108966  11-10-2019  18-10-2019
# 4   US-2019-108966  11-10-2019  18-10-2019
# 5   CA-2018-115812  09-06-2018  14-06-2018
# 6   CA-2018-115812  09-06-2018  14-06-2018
# 7   CA-2018-115812  09-06-2018  14-06-2018
# 8   CA-2018-115812  09-06-2018  14-06-2018
# 9   CA-2018-115812  09-06-2018  14-06-2018
# 10  CA-2018-115812  09-06-2018  14-06-2018
# 11  CA-2018-115812  09-06-2018  14-06-2018
# 12  CA-2021-114412  15-04-2021  20-04-2021
# 13  CA-2020-161389  05-12-2020  10-12-2020
# 14  US-2019-118983  22-11-2019  26-11-2019
# 15  US-2019-118983  22-11-2019  26-11-2019
# 16  CA-2018-105893  11-11-2018  18-11-2018
# 17  CA-2018-167164  13-05-2018  15-05-2018
# 18  CA-2018-143336  27-08-2018  01-09-2018
# 19  CA-2018-143336  27-08-2018  01-09-2018
# 20  CA-2018-143336  27-08-2018  01-09-2018
# ...

# %% [markdown]
# We can get desired columns from the file through this way i.e creating a seperate list and then printing it but it can be done through directly just passing the dessired columns which is given in above code in comments.

# %%
df_new =['order_id','order_date','ship_date']
df[df_new]
# Out:
#           order_id  order_date   ship_date
# 0   CA-2020-152156  08-11-2020  11-11-2020
# 1   CA-2020-152156  08-11-2020  11-11-2020
# 2   CA-2020-138688  12-06-2020  16-06-2020
# 3   US-2019-108966  11-10-2019  18-10-2019
# 4   US-2019-108966  11-10-2019  18-10-2019
# 5   CA-2018-115812  09-06-2018  14-06-2018
# 6   CA-2018-115812  09-06-2018  14-06-2018
# 7   CA-2018-115812  09-06-2018  14-06-2018
# 8   CA-2018-115812  09-06-2018  14-06-2018
# 9   CA-2018-115812  09-06-2018  14-06-2018
# 10  CA-2018-115812  09-06-2018  14-06-2018
# 11  CA-2018-115812  09-06-2018  14-06-2018
# 12  CA-2021-114412  15-04-2021  20-04-2021
# 13  CA-2020-161389  05-12-2020  10-12-2020
# 14  US-2019-118983  22-11-2019  26-11-2019
# 15  US-2019-118983  22-11-2019  26-11-2019
# 16  CA-2018-105893  11-11-2018  18-11-2018
# 17  CA-2018-167164  13-05-2018  15-05-2018
# 18  CA-2018-143336  27-08-2018  01-09-2018
# 19  CA-2018-143336  27-08-2018  01-09-2018
# 20  CA-2018-143336  27-08-2018  01-09-2018
# ...

# %% [markdown]
# As well as new data frame can be created with desired columns named as df_new and passed to do the above thing.

# %%
df['order_id']
# Out:
# 0     CA-2020-152156
# 1     CA-2020-152156
# 2     CA-2020-138688
# 3     US-2019-108966
# 4     US-2019-108966
# 5     CA-2018-115812
# 6     CA-2018-115812
# 7     CA-2018-115812
# 8     CA-2018-115812
# 9     CA-2018-115812
# 10    CA-2018-115812
# 11    CA-2018-115812
# 12    CA-2021-114412
# 13    CA-2020-161389
# 14    US-2019-118983
# 15    US-2019-118983
# 16    CA-2018-105893
# 17    CA-2018-167164
# 18    CA-2018-143336
# 19    CA-2018-143336
# 20    CA-2018-143336
# 21    CA-2020-137330
# 22    CA-2020-137330
# 23    US-2021-156909
# 24    CA-2019-106320
# 25    CA-2020-121755
# 26    CA-2020-121755
# 27    US-2019-150630
# 28    US-2019-150630
# 29    US-2019-150630
# 30    US-2019-150630
# 31    US-2019-150630
# 32    US-2019-150630
# 33    US-2019-150630
# 34    CA-2021-107727
# 35    CA-2020-117590
# 36    CA-2020-117590
# 37    CA-2019-117415
# 38    CA-2019-117415
# 39    CA-2019-117415
# 40    CA-2019-117415
# 41    CA-2021-120999
# 42    CA-2020-101343
# ...

# %% [markdown]
# It is basically passing the one column we need from the database when we want only want we can directly pass it. For more than one we have to create list as done in above codes.

# %%
df.order_id
# Out:
# 0     CA-2020-152156
# 1     CA-2020-152156
# 2     CA-2020-138688
# 3     US-2019-108966
# 4     US-2019-108966
# 5     CA-2018-115812
# 6     CA-2018-115812
# 7     CA-2018-115812
# 8     CA-2018-115812
# 9     CA-2018-115812
# 10    CA-2018-115812
# 11    CA-2018-115812
# 12    CA-2021-114412
# 13    CA-2020-161389
# 14    US-2019-118983
# 15    US-2019-118983
# 16    CA-2018-105893
# 17    CA-2018-167164
# 18    CA-2018-143336
# 19    CA-2018-143336
# 20    CA-2018-143336
# 21    CA-2020-137330
# 22    CA-2020-137330
# 23    US-2021-156909
# 24    CA-2019-106320
# 25    CA-2020-121755
# 26    CA-2020-121755
# 27    US-2019-150630
# 28    US-2019-150630
# 29    US-2019-150630
# 30    US-2019-150630
# 31    US-2019-150630
# 32    US-2019-150630
# 33    US-2019-150630
# 34    CA-2021-107727
# 35    CA-2020-117590
# 36    CA-2020-117590
# 37    CA-2019-117415
# 38    CA-2019-117415
# 39    CA-2019-117415
# 40    CA-2019-117415
# 41    CA-2021-120999
# 42    CA-2020-101343
# ...

# %% [markdown]
# Same as above, called as  dot notation, used to pass only one column

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# The above code is used to know what is the type of something like here it is telling that df is a dataframe

# %%
df_new1=df['order_id']
type(df_new1)
# Out:
# pandas.core.series.Series

# %% [markdown]
# So, here we passed only one column in the dataframe and we printed it's type, it is called as series when the dataframe has only one column in it.

# %%
df.iloc[0:6]
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 5  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0
# 4  OFF-ST-10000760  Office Supplies   22.4         2     2.5
# 5  FUR-FU-10001487        Furniture   48.9         7    14.2

# %% [markdown]
# To get specific rows through indexes we can use the iloc function which is acronym for index location. Also we have given that wanted to see rows from 0 to 5 so we mentioned [0:6] because the last is not not counted so it basically means from 0 until 5.

# %%
df.iloc[3:6]
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 5  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
#
#         product_id         category  sales  quantity  profit
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0
# 4  OFF-ST-10000760  Office Supplies   22.4         2     2.5
# 5  FUR-FU-10001487        Furniture   48.9         7    14.2

# %% [markdown]
# Similar as above just index is starting from 3 and ending at 5.

# %%
df.iloc[3:]
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 12  CA-2021-114412  15-04-2021  20-04-2021  Standard Class    AA-10480
# 13  CA-2020-161389  05-12-2020  10-12-2020  Standard Class    IM-15070
# 14  US-2019-118983  22-11-2019  26-11-2019  Standard Class    HP-14815
# ...

# %% [markdown]
# Starting from 3 till end

# %%
df.iloc[:4]
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0

# %% [markdown]
# from start till 3

# %%
df.iloc[[2,5,7]]
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 5  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
# 7  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
#
#         product_id         category  sales  quantity  profit
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 5  FUR-FU-10001487        Furniture   48.9         7    14.2
# 7  TEC-PH-10002275       Technology  907.2         6    90.7

# %% [markdown]
# To get specific indexs

# %%
df.iloc[[2,5,7],0:4]
# Out:
#          order_id  order_date   ship_date       ship_mode
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class
# 5  CA-2018-115812  09-06-2018  14-06-2018  Standard Class
# 7  CA-2018-115812  09-06-2018  14-06-2018  Standard Class

# %% [markdown]
# This will give us the only desired column index from the selected row indexs.

# %%
df.iloc[[2,5,7],[2,4,6]]
# Out:
#     ship_date customer_id       product_id
# 2  16-06-2020    DV-13045  OFF-LA-10000240
# 5  14-06-2018    BH-11710  FUR-FU-10001487
# 7  14-06-2018    BH-11710  TEC-PH-10002275

# %% [markdown]
# The above code is used to select the desired columns from the selected row indexes.

# %%
df.loc[0:10,['order_id','order_date','sales']]
# Out:
#           order_id  order_date   sales
# 0   CA-2020-152156  08-11-2020   262.0
# 1   CA-2020-152156  08-11-2020   731.9
# 2   CA-2020-138688  12-06-2020    14.6
# 3   US-2019-108966  11-10-2019   957.6
# 4   US-2019-108966  11-10-2019    22.4
# 5   CA-2018-115812  09-06-2018    48.9
# 6   CA-2018-115812  09-06-2018     7.3
# 7   CA-2018-115812  09-06-2018   907.2
# 8   CA-2018-115812  09-06-2018    18.5
# 9   CA-2018-115812  09-06-2018   114.9
# 10  CA-2018-115812  09-06-2018  1706.2

# %% [markdown]
# **In loc we can pass the index value through which we can get the actual value that is in the csv file. Almost similar as iloc but the biggest differnce is when we write [0:10]- iloc prints from starting till 9 whereas we can see in the output loc prints till 10 starting from 0 index.** Also [0:10]- it is called as index value

# %%
df_new = df.loc[0:10,['order_id','order_date','sales']]
df_new
# Out:
#           order_id  order_date   sales
# 0   CA-2020-152156  08-11-2020   262.0
# 1   CA-2020-152156  08-11-2020   731.9
# 2   CA-2020-138688  12-06-2020    14.6
# 3   US-2019-108966  11-10-2019   957.6
# 4   US-2019-108966  11-10-2019    22.4
# 5   CA-2018-115812  09-06-2018    48.9
# 6   CA-2018-115812  09-06-2018     7.3
# 7   CA-2018-115812  09-06-2018   907.2
# 8   CA-2018-115812  09-06-2018    18.5
# 9   CA-2018-115812  09-06-2018   114.9
# 10  CA-2018-115812  09-06-2018  1706.2

# %% [markdown]
# Here we can see we can create a new dataframe and do the same. Also previously if you see this code df_new =['order_id','order_date','ship_date']
# df[df_new] we were only able to select the exact column name but in loc we can select the row index as well
